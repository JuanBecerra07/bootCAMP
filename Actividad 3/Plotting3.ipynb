# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns 
# !pip install -q chart_studio
# !pip install -q plotly
import plotly.express as px

## Selecting Url to work with 
url="https://raw.githubusercontent.com/JuanBecerra07/bootCAMP-DS_JUAN-BECERRA-/main/Actividad%201/healthcare_dataset.csv"
df=pd.read_csv(url,sep=',',encoding='utf-8')
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df['Doctor']=df['Doctor'].apply(lambda x : x =='Diane Jackson')
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission  Doctor                   Hospital Insurance Provider  \
# ...

# %% [markdown]
# # Para esta actividad quise mejorar un poco la información relacionadad e ir más profundo por lo tanto quise realizar unas nuevas gráficas partiendo de la actividad 2

# %% [markdown]
# # ENFOQUE
#
# * UTILIZAR PANDAS  PARA PODER ENCONTRAR UNA RELACIÓN UTILIZANDO COMO PARTIDA LA ENFERMEDAD OBESIDAD
# * UTILIZAR PANDAS PARA ENCONTRAR UN RELACIÓN UTILIZANDO LA RAZÓN DE CONSULTA, CUANDO LOS EXÁMNENES DETERMINAN UN RESULTADO ABNORMAL

# %% [markdown]
# # PREGUNTA 1
# * Cual es la razón de mayor consulta dentro de los datos y presenta cierta diferencia frentes a las demas ?

# %%
Analisis = df[df['Test Results']== 'Abnormal']
Analisis2 = Analisis['Admission Type']
Analisis2.value_counts()
sns.barplot(x=Analisis2.index , y= Analisis2.values)
plt.xticks(rotation=45)
plt.xlabel('Amount of Consults')
plt.ylabel('Reason')
plt.title('Consult Graf.')
# Out:
# Text(0.5, 1.0, 'Consult Graf.')

# %% [markdown]
# # RESPUESTA 1
# * Mayor razón de consulta dentro de los hospitales es EMERGENCY y si presenta una cantidad considerable superando los 5000 cuando las demás causas no llegan ni siquiera a ese valor por lo tantos los hospitales deben presentar mayor atención a sus sales de emergency.

# %% [markdown]
# # PREGUNTA 2
# Al saber que la razón de consulta primordial es Emergency, cuando los exámenes determinan un resultado abnormal que determinaciones podemos tomar frente al grupo que presenta obesidad frente a las otras condiciones?

# %%
Analisis
Analisis3 = Analisis[df['Admission Type']== 'Emergency']
MedP = Analisis3['Medical Condition']
MedP

sns.barplot(x=MedP.value_counts().index , y = MedP.value_counts().values,palette = "Blues")
# Out:
# /tmp/ipykernel_80500/680992806.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Analisis3 = Analisis[df['Admission Type']== 'Emergency']
# /tmp/ipykernel_80500/680992806.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=MedP.value_counts().index , y = MedP.value_counts().values,palette = "Blues")
# <Axes: xlabel='Medical Condition'>

# %% [markdown]
# # RESPUESTA 2
# * La obesidad es la enfermedad más presente dentro de las consultas por emergencia con resultados abnormales, lo cual presenta un caso de interés para los hospitales por la rápida respuesta que se debe tener en estos casos

# %% [markdown]
# # Pregunta 3
# * EN UN HOSPITAL ES MUY CRÍTICO SABER EL TIPO DE SANGRE DE UN DIABÉTICO YA QUE SI LLEGAN EN POR CORTE O TRAUMA SERÁ NECESARIA DE INMEDIATO PARA EVITAR LA AMPUTACIÓN DEL MIEMBRO

# %%
MedP2 = Analisis3[df['Medical Condition']=='Obesity']
MedPO=MedP2['Blood Type']

sns.barplot(x=MedPO.value_counts().index , y = MedPO.value_counts().values,palette = "Reds")

plt.xlabel('RH FACTOR')
plt.ylabel('Frec')
plt.title('Frec RH')
# Out:
# /tmp/ipykernel_80500/3358872778.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   MedP2 = Analisis3[df['Medical Condition']=='Obesity']
# /tmp/ipykernel_80500/3358872778.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=MedPO.value_counts().index , y = MedPO.value_counts().values,palette = "Reds")
# Text(0.5, 1.0, 'Frec RH')

# %% [markdown]
# # Respuest 3
#
# * Enfocar las reservas sanguineas de los tipos AB- , B- Y AB+ para pacientes con obesidad , con un control de cantidad para los otros tipos de sangre pero sin presentar la mismam urgencia
# * Podemos observar que los tipos A+ ,O+ y B+ se encuentran en la misma linea lo cual puede llevar a una investigación cuyo grupo de estudio solo tenga esos tipos sanguineas y poder encontra una relación con dicha enfermedad.

# %% [markdown]
# # En la grafica inferior
# * podemos observar la variación de la edad según la condición médica y al mismo tiempo tomando en cuenta solo las consultas por emergencia  donde encontramos que :
#      * la hipertensión y el cancer en edad avanzanda es la que más consultas por emergencia con una diferencia de solo 0.5
#      * Preocupante que la artitis tiene una edad mínima de 32 años y la edad média mínima de 48 excluyendo los datos máximos
#      * Dentro de la facturación la obesidad es la que más factura

# %%
px.box(Analisis3, x='Medical Condition',y='Age',title= 'Medical Condition')
# Out:
# <div>                            <div id="1df6ce1e-8228-4774-84d5-95b7adba31f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1df6ce1e-8228-4774-84d5-95b7adba31f9")) {                    Plotly.newPlot(                        "1df6ce1e-8228-4774-84d5-95b7adba31f9",                        [{"alignmentgroup":"True","hovertemplate":"Medical Condition=%{x}\u003cbr\u003eAge=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Cancer","Obesity","Hypertension","Arthritis","Cancer","Asthma","Obesity","Cancer","Arthritis","Cancer","Arthritis","Cancer","Arthritis","Arthritis","Obesity","Obesity","Diabetes","Arthritis","Hypertension","
# ...

# %%
fig=px.bar(Analisis3.sort_values(by=['Billing Amount'],ascending=True),
y= 'Billing Amount', x='Medical Condition',
text='Billing Amount', 
color='Medical Condition',
title= 'Amount of Billing by Emergency'

)


fig
# Out:
# <div>                            <div id="2a3925ba-77e3-4563-9261-dcb101548b71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a3925ba-77e3-4563-9261-dcb101548b71")) {                    Plotly.newPlot(                        "2a3925ba-77e3-4563-9261-dcb101548b71",                        [{"alignmentgroup":"True","hovertemplate":"Medical Condition=%{x}\u003cbr\u003eBilling Amount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Obesity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Obesity","offsetgroup":"Obesity","orientation":"v","showlegend":true,"text":[1000.1808370217516,1032.6402799537905,1558.0693002955077,1599.6406981832902,2029.826589406668,2232.198069361695,2742.3709276833183,2991.585877151348,3167.4111565989
# ...

# %%
px.box(Analisis3, x='Medical Condition',y='Billing Amount',)
# Out:
# <div>                            <div id="8c1abc6e-747b-432e-b773-c307f4451844" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c1abc6e-747b-432e-b773-c307f4451844")) {                    Plotly.newPlot(                        "8c1abc6e-747b-432e-b773-c307f4451844",                        [{"alignmentgroup":"True","hovertemplate":"Medical Condition=%{x}\u003cbr\u003eBilling Amount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Cancer","Obesity","Hypertension","Arthritis","Cancer","Asthma","Obesity","Cancer","Arthritis","Cancer","Arthritis","Cancer","Arthritis","Arthritis","Obesity","Obesity","Diabetes","Arthritis","Hype
# ...
