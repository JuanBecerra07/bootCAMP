# %%
import pandas as pd 
## Selecting Url to work with 
url="https://raw.githubusercontent.com/JuanBecerra07/bootCAMP-DS_JUAN-BECERRA-/main/Actividad%201/healthcare_dataset.csv"
df=pd.read_csv(url,sep=',',encoding='utf-8')
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
blood_TYPE=df["Blood Type"]
##Esto me dice cual es el tipo de sangre mas afectado
blood_TYPE.value_counts()
##AB- es la mas afectada
# Out:
# Blood Type
# AB-    1275
# AB+    1258
# B-     1252
# O+     1248
# O-     1244
# B+     1244
# A+     1241
# A-     1238
# Name: count, dtype: int64

# %%
ill = df["Medical Condition"]
ill.value_counts()## Entregas Asma como la predominantes ahora a crear un nuevo DF para poder saber que tipos de sangre sufren + de asma
ill_asma = df[df['Medical Condition']=='Asthma']
ill_BT = ill_asma["Blood Type"]
ill_BT.value_counts() 
## ahora sabemos que el 0+ es el + predominanate dentro de las personas con asma
## Ahora para poder el DF de los pacientes con asma y 0+ hacemos lo siguiente 
ill_asma_0= df[df['Blood Type']== 'O+']
ill_asma_0
# Out:
#                          Name  Age  Gender Blood Type Medical Condition  \
# 1                 Ruben Burns   35    Male         O+            Asthma
# 15               Brian Dorsey   32  Female         O+         Arthritis
# 18        Desiree Williams MD   66    Male         O+           Obesity
# 29    Shannon Fitzpatrick DVM   35  Female         O+      Hypertension
# 44              Lauren Barton   34    Male         O+      Hypertension
# ...                       ...  ...     ...        ...               ...
# 9957            Alicia Peters   71  Female         O+         Arthritis
# 9968              Emma Mccann   51  Female         O+           Obesity
# 9969             Darius Smith   63  Female         O+            Asthma
# 9977            James Calhoun   84    Male         O+            Cancer
# 9992        Gabriel Rodriguez   37    Male         O+      Hypertension
#
#      Date of Admission            Doctor                     Hospital  \
# ...

# %%
## otra forma de filtrar todo

# %%
# Out:
#                          Name  Age  Gender Blood Type Medical Condition  \
# 1                 Ruben Burns   35    Male         O+            Asthma
# 15               Brian Dorsey   32  Female         O+         Arthritis
# 18        Desiree Williams MD   66    Male         O+           Obesity
# 29    Shannon Fitzpatrick DVM   35  Female         O+      Hypertension
# 44              Lauren Barton   34    Male         O+      Hypertension
# ...                       ...  ...     ...        ...               ...
# 9957            Alicia Peters   71  Female         O+         Arthritis
# 9968              Emma Mccann   51  Female         O+           Obesity
# 9969             Darius Smith   63  Female         O+            Asthma
# 9977            James Calhoun   84    Male         O+            Cancer
# 9992        Gabriel Rodriguez   37    Male         O+      Hypertension
#
#      Date of Admission            Doctor                     Hospital  \
# ...

# %%
Gender = df[df['Gender']=='Female']
Gender
blood_TYPE_G =Gender['Blood Type']
blood_TYPE_G.value_counts()
## tipo de sangre mas afecatda en mujeres
# Out:
# Blood Type
# AB-    671
# O+     641
# B+     640
# AB+    637
# B-     635
# A-     633
# A+     629
# O-     589
# Name: count, dtype: int64

# %%
## muestra la info del data frame que tienes 
df.info()
df.describe()
## preguntar este ultimo
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
#@#Muestra los valores unicos
df["Age"].unique()
## Muestra cuantas veces aparece un valor 
df["Age"].value_counts()
df["Name"].value_counts()
df.to_csv("primer df")
