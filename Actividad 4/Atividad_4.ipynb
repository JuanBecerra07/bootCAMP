# %% [markdown]
# # Contexto Comercial
# Tenemos la informacion de una serie de Hospitales dentro de los Estados Unidos los cuales atienden enfermedades como Diabetes.Asthma,Obesidad, entre otras catalogadas como las más comúnes dentro de la socidad actual. La FDA requiere informacion como en que momentos del año los pacientes atienden más al hospital y que tipo de enfermedades los generan, Como como la distribucióni de genero puede impactar dependiendo de las enfermedades más crónicas y como se ve esto re flejado en la facturación de dicho Hospital. Todo esto para lograr saber como distribuir correctamente sus medicamentos, subsidios y personal para atender a todos los usuarios. Porfavor realiza un analisis descriptivo de los datos que arrojen valores de impacto en la atención hospitalaria.

# %% [markdown]
# * Instalación de Pandas y librerías de diseño de gráficos necesarios

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns 

## Selecting Url to work with 
url="https://raw.githubusercontent.com/JuanBecerra07/bootCAMP-DS_JUAN-BECERRA-/main/Actividad%201/healthcare_dataset.csv"
df=pd.read_csv(url,sep=',',encoding='utf-8')
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %% [markdown]
# * Incialición del motor de para el manejo de datos con Sql alchemy

# %%
import os 
os.getcwd()
from  sqlalchemy import create_engine, text 
pd.options.display.max_rows = 100
ruta="./"

# %%
# Definir el motor 
engine = create_engine('sqlite://')
print(engine)
# engine.dispose()
# Out:
# Engine(sqlite://)

# %% [markdown]
# # Preguntas o Hipótesis a resolver
#
# * Hay una enfermedad que esté incurriendo en mayores gastos dentro del sistema de salud y si es así como se distribuye dentro del segmento de los hospitales y genero.
# * Hay algún tipo de sangre mayormente afectado que requira de una atención prioritaria dentro del espectro ?
# * Encontrar una relación entre las epocas de admisión y salida de los pacientes es crucial para distribuir al carga laboral ?
# * Hay una corelación entre la edad,la sangre y el tipo de enfermedades ?
# * Que hospitales se encuentran mayor mente impactados por la cantidad de pacientes ?
# * Hay alg[un de tipo de corelación entre las enfermedades , genero y edades de los pacientes ?

# %% [markdown]
# # EDA

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64
